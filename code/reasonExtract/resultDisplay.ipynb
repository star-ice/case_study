# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import os
import plotly.express as px
import plotly
import plotly.graph_objects as go
import plotly as py
import plotly.offline as offline
offline.init_notebook_mode(connected=True)
from plotly.subplots import make_subplots
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
all_cases = pd.read_csv('/Users/starice/OwnFiles/cityu/RA/case_study/data/total_extracted_result/all_cases.csv', encoding="utf-8")
all_cases['case_id'].drop_duplicates()
all_cases = all_cases[all_cases['defendant'] != all_cases['lawyer']]

# %% [markdown]
# <h2>Read and merge all case reason csv files</h2>

# %%
files = os.listdir("/Users/starice/OwnFiles/cityu/RA/case_study/case_study_result/case_reasons")
df = pd.DataFrame()
for file in files:
    file_path = "/Users/starice/OwnFiles/cityu/RA/case_study/case_study_result/case_reasons/" + file
    tdf = pd.read_csv(file_path)
    df = df.append(tdf, ignore_index=True)

df = df.drop('Unnamed: 0', axis=1)

# %%
reasonDf = all_cases.merge(df, on="case_id", how='inner')
reasonDf = reasonDf.drop('Unnamed: 0', axis=1)
reasonDf = reasonDf[['case_id', 'judgement_date', 'is_success', 'procedure', 
                    'legalfee', 'objectmoney', 'penalty', 'province', 'city', 
                    'district', 'year', 'month', 'day', 'lawyer', 'case_reason', 
                    'is_import']].drop_duplicates().reset_index().drop('index', axis=1)

reasonDf['case_reason'] = reasonDf['case_reason'].apply(lambda r: eval(r))
reasonDf = reasonDf.explode('case_reason').reset_index(drop=True)

reasonDict = {
    "reason1": "标签、配料表、外包装违规", 
    "reason2": "假冒产品", 
    "reason3": "保质期、生产日期", 
    "reason4": "原材料、添加剂", 
    "reason5": "商标", 
    "reason6": "出入境检验、检疫证明、来源证明", 
    "reason7": "生产许可证、生产标准、证明文件", 
    "reason8": "餐饮食品安全", 
    "reason9": "是否为真实消费者", 
    "reason10": "食品无国家标准或未通过安全性评估", 
    "reason11": "产品质检不合格、质量有问题"
}

reasonDf['case_reason_txt'] = reasonDf['case_reason'].map(reasonDict)
reasonDf.head(1)
# Out:
#                     case_id judgement_date is_success procedure  legalfee  \
# 0  57ab9058c2265c28a560195d     2014-01-13       TRUE        一审     244.0
#
#    objectmoney  penalty province city district  year  month  day lawyer  \
# 0       374.48   3744.8      浙江省  杭州市      西湖区  2014      1   13    NaN
#
#   case_reason  is_import  case_reason_txt
# 0     reason7      False  生产许可证、生产标准、证明文件

# %%
a = list(reasonDf[reasonDf['case_reason_txt']=="假冒产品"]['case_id'].drop_duplicates())
with open("假冒产品_cid.txt", "w") as f:
    for i in a:
        f.write(i)
        f.write("\n")

# %% [markdown]
# <h2>Compute reason distribution for cases</h2>

# %%
reasonDist_cc = reasonDf.groupby('case_reason_txt')['case_id'].nunique().reset_index()
reasonDist_cc.rename(columns={"case_id": "case_count"}, inplace=True)

reasonDist_sc = reasonDf[reasonDf['is_success']=='TRUE'].groupby('case_reason_txt')['case_id'].nunique().reset_index()
reasonDist_sc.rename(columns={"case_id": "success_count"}, inplace=True)
reasonDist = reasonDist_cc.merge(reasonDist_sc, how="left").fillna(0)

# %%
reasonDist
# Out:
#      case_reason_txt  case_count  success_count
# 0      产品质检不合格、质量有问题        4385         2605.0
# 1           保质期、生产日期       13980        12756.0
# 2               假冒产品         122           72.0
# 3    出入境检验、检疫证明、来源证明        1704         1244.0
# 4            原材料、添加剂        3913         3117.0
# 5                 商标          94           56.0
# 6           是否为真实消费者           6            0.0
# 7       标签、配料表、外包装违规       21026        14934.0
# 8    生产许可证、生产标准、证明文件        1248          935.0
# 9   食品无国家标准或未通过安全性评估          31           29.0
# 10            餐饮食品安全        1042          514.0

# %%
reasonDist_year = reasonDf.groupby(['year', 'case_reason_txt'])['case_id'].nunique().reset_index()
reasonDist_year.rename(columns={"case_id": "case_count"}, inplace=True)

# %%
reasonDist_year.head(1)
# Out:
#    year case_reason_txt  case_count
# 0  2014   产品质检不合格、质量有问题         138

# %% [markdown]
# <h2>Display</h2>

# %% [markdown]
# <h3>Case count distribution</h3>

# %%
fig = px.bar(
    reasonDist,
    x = 'case_reason_txt', 
    y = ['case_count', 'success_count'], 
    barmode="group"
)
fig.show()
# Out:
# <div>                            <div id="5998cb29-21ce-42e9-b34b-bcc3d63d63b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5998cb29-21ce-42e9-b34b-bcc3d63d63b3")) {                    Plotly.newPlot(                        "5998cb29-21ce-42e9-b34b-bcc3d63d63b3",                        [{"alignmentgroup": "True", "hovertemplate": "variable=case_count<br>case_reason_txt=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "case_count", "marker": {"color": "#636efa"}, "name": "case_count", "offsetgroup": "case_count", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u5047\u5192\u4ea7\u54c1", "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u5546\u6807", "\u662f\u5426\u4e3a\u771f\u5b9e\u6d88\u8d39\u8005", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u98df\u54c1\u65e0\u56fd\u5bb6\u6807\u51c6\u6216\u672a\u901a\u8fc7\u5b89\u5168\u6027\u8bc4\u4f30", "\u9910\u996e\u98df\u54c1\u5b89\u5168"], "xaxis": "x", "y": [4385.0, 13980.0, 122.0, 1704.0, 3913.0, 94.0, 6.0, 21026.0, 1248.0, 31.0, 1042.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=success_count<br>case_reason_txt=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "success_count", "marker": {"color": "#EF553B"}, "name": "success_count", "offsetgroup": "success_count", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u5047\u5192\u4ea7\u54c1", "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u5546\u6807", "\u662f\u5426\u4e3a\u771f\u5b9e\u6d88\u8d39\u8005", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u98df\u54c1\u65e0\u56fd\u5bb6\u6807\u51c6\u6216\u672a\u901a\u8fc7\u5b89\u5168\u6027\u8bc4\u4f30", "\u9910\u996e\u98df\u54c1\u5b89\u5168"], "xaxis": "x", "y": [2605.0, 12756.0, 72.0, 1244.0, 3117.0, 56.0, 0.0, 14934.0, 935.0, 29.0, 514.0], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": ...

# %% [markdown]
# <h3>Reason count distribution with year</h3>

# %%
fig = px.line(
    reasonDist_year, 
    x = 'year', 
    y = 'case_count', 
    color = "case_reason_txt"
    
)
fig.show()
# 案件原因处理时要去掉公益诉讼类案件
# Out:
# <div>                            <div id="7c8ac088-7ad9-4358-afeb-a7d361fe6744" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c8ac088-7ad9-4358-afeb-a7d361fe6744")) {                    Plotly.newPlot(                        "7c8ac088-7ad9-4358-afeb-a7d361fe6744",                        [{"hovertemplate": "case_reason_txt=\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [138, 258, 547, 1622, 930, 848, 42], "yaxis": "y"}, {"hovertemplate": "case_reason_txt=\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [160, 524, 1961, 5200, 3548, 2528, 59], "yaxis": "y"}, {"hovertemplate": "case_reason_txt=\u5047\u5192\u4ea7\u54c1<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u5047\u5192\u4ea7\u54c1", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "\u5047\u5192\u4ea7\u54c1", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1, 11, 16, 30, 8, 56], "yaxis": "y"}, {"hovertemplate": "case_reason_txt=\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [29, 143, 233, 559, 418, 302, 20], "yaxis": "y"}, {"hovertemplate": "case_reason_txt=\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [101, 419, 717, 1375, 506, 761, 34], "yaxis": "y"}, {"hovertemplate": "case_reason_txt=\u5546\u6807<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u5546\u6807", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "\u5546\u6807", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [8, 12, 17, 21, 12, 21, 3], "yaxis": "y"}, {"hovertemplate": "case_reason_txt=\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4<br>year=%{x}<br>case_count=%{y}<extra></extra>", "legendgroup": "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "orientation": "v", "showlegend": true, "type": "scatter", "x":  ...

# %% [markdown]
# <h3>Distribution of legalfee, objectmoney, and penalty with different reasons</h3>

# %%
fig_legalfee = px.box(
    reasonDf[['case_reason_txt', 'legalfee']].drop_duplicates(), 
    x = 'case_reason_txt', 
    y = 'legalfee'
)
fig_legalfee.update_yaxes(type="log")
fig_legalfee.show()
# Out:
# <div>                            <div id="ceff0d4d-c107-4092-a601-ea94fad6951a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ceff0d4d-c107-4092-a601-ea94fad6951a")) {                    Plotly.newPlot(                        "ceff0d4d-c107-4092-a601-ea94fad6951a",                        [{"alignmentgroup": "True", "hovertemplate": "case_reason_txt=%{x}<br>legalfee=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u98df\u54c1\u65e0\u56fd\u5bb6\u6807\u51c6\u6216\u672a\u901a\u8fc7\u5b89\u5168\u6027\u8bc4\u4f30", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u5546\u6807", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u9910\u996e\u98df\u54c1\u5b89\u5168", "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u9910\u996e\u98df\u54c1\u5b89\u5168", "\u6807\u7b7e\u3001\u914d\u ...

# %%
fig_objm = px.box(
    reasonDf[['case_reason_txt', 'objectmoney']].drop_duplicates(), 
    x = 'case_reason_txt', 
    y = 'objectmoney'
)
fig_objm.update_yaxes(type="log")
fig_objm.show()
# Out:
# <div>                            <div id="c2ab021e-41bd-493e-80dc-5656259503c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2ab021e-41bd-493e-80dc-5656259503c2")) {                    Plotly.newPlot(                        "c2ab021e-41bd-493e-80dc-5656259503c2",                        [{"alignmentgroup": "True", "hovertemplate": "case_reason_txt=%{x}<br>objectmoney=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u98df\u54c1\u65e0\u56fd\u5bb6\u6807\u51c6\u6216\u672a\u901a\u8fc7\u5b89\u5168\u6027\u8bc4\u4f30", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u5546\u6807", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u591 ...

# %%
fig_penalty = px.box(
    reasonDf[reasonDf['is_success']=="TRUE"][['case_reason_txt', 'penalty']].drop_duplicates(), 
    x = 'case_reason_txt', 
    y = 'penalty'
)
fig_penalty.update_yaxes(type="log")
fig_penalty.show()
# Out:
# <div>                            <div id="55d3de0f-d169-4eb0-8146-a3494791e9d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55d3de0f-d169-4eb0-8146-a3494791e9d3")) {                    Plotly.newPlot(                        "55d3de0f-d169-4eb0-8146-a3494791e9d3",                        [{"alignmentgroup": "True", "hovertemplate": "case_reason_txt=%{x}<br>penalty=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u98df\u54c1\u65e0\u56fd\u5bb6\u6807\u51c6\u6216\u672a\u901a\u8fc7\u5b89\u5168\u6027\u8bc4\u4f30", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u4ea7\u54c1\u8d28\u68c0\u4e0d\u5408\u683c\u3001\u8d28\u91cf\u6709\u95ee\u9898", "\u51fa\u5165\u5883\u68c0\u9a8c\u3001\u68c0\u75ab\u8bc1\u660e\u3001\u6765\u6e90\u8bc1\u660e", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u751f\u4ea7\u8bb8\u53ef\u8bc1\u3001\u751f\u4ea7\u6807\u51c6\u3001\u8bc1\u660e\u6587\u4ef6", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u539f\u6750\u6599\u3001\u6dfb\u52a0\u5242", "\u4fdd\u8d28\u671f\u3001\u751f\u4ea7\u65e5\u671f", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8fdd\u89c4", "\u6807\u7b7e\u3001\u914d\u6599\u8868\u3001\u5916\u5305\u88c5\u8 ...
